# %%
from tabletennistrader import getBoxScores, processBoxScores, Pipeline, Trader
import pandas as pd
import time

# %% [markdown]
# # Webscrape and process new box scores

# %%
# Box scores file in repo contains scores from 2024-08-02 to 2025-08-30
# This code will scrape the box scores for 2025-08-31
# Run getBoxScores() without any arguments to scrape all box scores up to current date
start = time.time()
getBoxScores(startDate = '2025-08-31', endDate = '2025-08-31')
end = time.time()
print(f'Finished in {end - start}s')
# Out:
# Scraping 2025-08-31
# Scraping Tournament А18. league 900-1000
# Scraping match 251218
# Scraping match 251219
# Scraping match 251220
# Scraping match 251221
# Scraping match 251222
# Scraping match 251223
# Scraping match 251450
# Scraping match 251451
#
#
# Scraping Tournament А16. league 600-700
# Scraping match 251456
# Scraping match 251457
# Scraping match 251160
# Scraping match 251161
# Scraping match 251162
# Scraping match 251163
# Scraping match 251164
# Scraping match 251165
#
#
# Scraping Tournament A12. league 700-800
# Scraping match 251092
# Scraping match 251093
# Scraping match 251094
# Scraping match 251095
# Scraping match 251096
# Scraping match 251097
# Scraping match 251452
# Scraping match 251453
#
#
# Scraping Tournament A14. league 800-900
# Scraping match 251126
# Scraping match 251127
# Scraping match 251128
# Scraping match 251129
# Scraping match 251130
# Scraping match 251131
# Scraping match 251454
# Scraping match 251455
#
#
# Scraping Tournament А17. league 600-700
# Scraping match 251458
# Scraping match 251459
# Scraping match 251184
# Scraping match 251185
# Scraping match 251186
# Scraping match 251187
# Scraping match 251188
# Scraping match 251189
#
#
# Scraping Tournament А18. league 900-1000
# Scraping match 251212
# Scraping match 251213
# Scraping match 251214
# Scraping match 251215
# Scraping match 251216
# Scraping match 251217
# Scraping match 251448
# Scraping match 251449
#
#
# Scraping Tournament А17. league 800-900
# Scraping match 251178
# Scraping match 251179
# Scraping match 251180
# Scraping match 251181
# Scraping match 251182
# Scraping match 251183
# Scraping match 251440
# Scraping match 251441
#
#
# Scraping Tournament A12. league 700-800
# Scraping match 251086
# Scraping match 251087
# Scraping match 251088
# Scraping match 251089
# Scraping match 251090
# Scraping match 251091
# Scraping match 251442
# Scraping match 251443
#
#
# Scraping Tournament А16. league 900-1000
# Scraping match 251154
# Scraping match 251155
# Scraping match 251156
# Scraping match 251157
# Scraping match 251158
# Scraping match 251159
# Scraping match 251444
# Scraping match 251445
#
#
# Scraping Tournament A14. league 700-800
# Scraping match 251120
# Scraping match 251121
# Scraping match 251122
# Scraping match 251123
# Scraping match 251124
# Scraping match 251125
# Scraping match 251446
# Scraping match 251447
#
#
# Scraping Tournament А17. league 800-900
# Scraping match 251172
# Scraping match 251173
# Scraping match 251174
# Scraping match 251175
# Scraping match 251176
# Scraping match 251177
# Scraping match 251430
# Scraping match 251431
#
#
# Scraping Tournament А16. league 900-1000
# Scraping match 251434
# Scraping match 251435
# Scraping match 251148
# Scraping match 251149
# Scraping match 251150
# Scraping match 251151
# Scraping match 251152
# Scraping match 251153
#
#
# Scraping Tournament A14. league 700-800
# Scraping match 251114
# Scraping match 251115
# Scraping match 251116
# Scraping match 251117
# Scraping match 251118
# Scraping match 251119
# Scraping match 251436
# Scraping match 251437
#
#
# Scraping Tournament A12. league 350-400
# Scraping match 251080
# Scraping match 251081
# Scraping match 251082
# Scraping match 251083
# Scraping match 251084
# Scraping match 251085
# Scraping match 251432
# Scraping match 251433
#
#
# Scraping Tournament А18. league 400-450
# Scraping match 251206
# Scraping match 251207
# Scraping match 251208
# Scraping match 251209
# Scraping match 251210
# Scraping match 251211
# Scraping match 251438
# Scraping match 251439
#
#
# Scraping Tournament А18. league 600-700
# Scraping match 251200
# Scraping match 251201
# Scraping match 251202
# Scraping match 251203
# Scraping match 251204
# Scraping match 251205
# Scraping match 251420
# Scraping match 251421
#
#
# Scraping Tournament А16. league 300-350
# Scraping match 251428
# Scraping match 251429
# Scraping match 251142
# Scraping match 251143
# Scraping match 251144
# Scraping match 251145
# Scraping match 251146
# Scraping match 251147
#
#
# Scraping Tournament А17. league 800-900
# Scraping match 251168
# Scraping match 251169
# Scraping match 251170
# Scraping match 251171
# Scraping match 251422
# Scraping match 251423
# Scraping match 251166
# Scraping match 251167
#
#
# Scraping Tournament A14. league 250-300
# Scraping match 251424
# Scraping match 251425
# Scraping match 251108
# Scraping match 251109
# Scraping match 251110
# Scraping match 251111
# Scraping match 251112
# Scraping match 251113
#
#
# Scraping Tournament A12. league 250-300
# Scraping match 251074
# Scraping match 251075
# Scraping match 251076
# Scraping match 251077
# Scraping match 251078
# Scraping match 251079
# Scraping match 251426
# Scraping match 251427
#
#
# Scraping Tournament A12. league 400-450
# Scraping match 251265
# Scraping match 251266
# Scraping match 250902
# Scraping match 250903
# Scraping match 250904
# Scraping match 250905
# Scraping match 250906
# Scraping match 250907
# Scraping match 250908
# Scraping match 250909
# Scraping match 250910
# Scraping match 250911
#
#
# Scraping Tournament А17. league 600-700
# Scraping match 251268
# Scraping match 251269
# Scraping match 250994
# Scraping match 250995
# Scraping match 250996
# Scraping match 250997
# Scraping match 250998
# Scraping match 250999
# Scraping match 251000
# Scraping match 251001
# Scraping match 251002
# Scraping match 251003
#
#
# Scraping Tournament A14. league 900-1000
# Scraping match 250944
# Scraping match 250945
# Scraping match 251264
# Scraping match 251267
# Scraping match 250936
# Scraping match 250937
# Scraping match 250938
# Scraping match 250939
# Scraping match 250940
# Scraping match 250941
# Scraping match 250942
# Scraping match 250943
#
#
# Finished in 359.2872579097748s

# %%
# Newly scraped box scores will not be included in ratings until they are processed
start = time.time()
processBoxScores()
end = time.time()
print(f'Finished in {end - start}s')
# Out:
# Processing box scores...
# Finished in 51.751182317733765s

# %% [markdown]
# # Create and execute Pipeline to generate new player ratings. Pipeline can be optimized/tuned using the following parameters:
# * additiveSmoothing: If a player wins $a$ out of their $b$ service points in a set and additive smoothing is set to $c$, then the target variable for the regression problem is $\frac{a + c}{b + 2c}$. $c$ should always be positive.
# * ratingsWindowDays: The cutoff for how far back box score data is included in the calculation of the player ratings. Increasing this will increase runtime of the Pipeline.
# * ratingsHalfLifeDays: Scores are time-weighted so that more recent scores have more weight in the calculation of the player ratings. This is the number of days it takes for a data point to have its weight decreased by 50%.
# * regularizationAlpha: Ratings are calculated by solving a regression problem that is by itself under-determined, $L2$-regularization is used to ensure stability/uniqueness of the solution, this is the strength of the regularization.

# %%
start = time.time()
pipeline = Pipeline(additiveSmoothing = 1, ratingsWindowDays = 360, ratingsHalfLifeDays = 60, regularizationAlpha = 0.01)
pipeline.execute()
end = time.time()
print(f'Finished in {end - start}s')
# Out:
# Preparing ratings corpus...
# Solving mu ratings...
# Solving epsilon ratings...
# Finished in 283.0961105823517s

# %%
# View player ratings
pipeline.playerMuRatings
# Out:
#                  serveElo  returnElo
# player
# Adam Radim       0.160778  -0.114321
# Adamec Miroslav  0.059232  -0.129189
# Andrle Tomas     0.012962  -0.086958
# Babicka Lukas    0.121247  -0.121094
# Babinek Jiri     0.330918   0.238413
# ...                   ...        ...
# Zmuda Petr       0.296791   0.136585
# Zobac Michal     0.603547   0.485102
# Zoha Libor      -0.020606  -0.164096
# Zraly Daniel    -0.534389  -0.680078
# Zuzanek Jiri     0.322066   0.246518
#
# [675 rows x 2 columns]

# %%
pipeline.playerEpsilonRatings
# Out:
#                                                   covarianceMatrix
# player
# Adam Radim       [[0.17438695679371324, 0.036213411784327], [0....
# Adamec Miroslav  [[0.20658639970143894, 0.029430026982798754], ...
# Andrle Tomas     [[0.2300680175812841, 0.038122542515775716], [...
# Babicka Lukas    [[0.2054700123493705, 0.03840921593608696], [0...
# Babinek Jiri     [[0.18702871271160432, 0.01611649988813381], [...
# ...                                                            ...
# Zmuda Petr       [[0.20945402053769085, 0.030182506368930433], ...
# Zobac Michal     [[0.1903142323612401, 0.03311382791121307], [0...
# Zoha Libor       [[0.2550339359402632, 0.06754344206582065], [0...
# Zraly Daniel     [[0.24294216339822192, 0.04708374681260749], [...
# Zuzanek Jiri     [[0.20829240877127894, 0.04232973867621612], [...
#
# [675 rows x 1 columns]

# %% [markdown]
# # Create Trader and use pretrade to print daily matchups (i.e. matchups the day after the most recently scraped box scores) to betLog.xlsx
#
# ## To use betLog.xlsx, just input the American betting odds for each respective player under bookPlayerOdds (for the player under the player column) and bookOpponentOdds (for the player under the opponent column). The recommended bet for each player will be automatically calculated under playerWager and opponentWager. It is possible that both of these values will be 0, which means that the simulated win probability is close to the win probability implied by the betting odds.
#
# ## When the match is over, enter 'player' or 'opponent' under the winner column depending on who won (you can enter 'push' if the match was cancelled) and the win/loss amount will be calculated under the delta column.

# %%
start = time.time()
trader = Trader()
trader.pretrade()
end = time.time()
print(f'Finished in {end - start}s')
# Out:
# Fetching tournaments for 2025-09-01...
# Fetching matchups for tournament Tournament А18. league 800-900... (1/23)
# Fetching matchups for tournament Tournament А16. league 800-900... (2/23)
# Fetching matchups for tournament Tournament A12. league 600-700... (3/23)
# Fetching matchups for tournament Tournament A14. league 550-600... (4/23)
# Fetching matchups for tournament Tournament А17. league 1000-1100... (5/23)
# Fetching matchups for tournament Tournament А18. league 800-900... (6/23)
# Fetching matchups for tournament Tournament А17. league 900-1000... (7/23)
# Fetching matchups for tournament Tournament A12. league 600-700... (8/23)
# Fetching matchups for tournament Tournament А16. league 700-800... (9/23)
# Fetching matchups for tournament Tournament A14. league 900-1000... (10/23)
# Fetching matchups for tournament Tournament А17. league 450-500... (11/23)
# Fetching matchups for tournament Tournament А16. league 700-800... (12/23)
# Fetching matchups for tournament Tournament A14. league 400-450... (13/23)
# Fetching matchups for tournament Tournament A12. league 550-600... (14/23)
# Fetching matchups for tournament Tournament А18. league 550-600... (15/23)
# Fetching matchups for tournament Tournament А18. league 600-700... (16/23)
# Fetching matchups for tournament Tournament А16. league 600-700... (17/23)
# Fetching matchups for tournament Tournament А17. league 450-500... (18/23)
# Fetching matchups for tournament Tournament A14. league 400-450... (19/23)
# Fetching matchups for tournament Tournament A12. league 300-350... (20/23)
# Fetching matchups for tournament Tournament A12. league 600-700... (21/23)
# Fetching matchups for tournament Tournament А17. league 500-550... (22/23)
# Fetching matchups for tournament Tournament A14. league 900-1000... (23/23)
# Simulating Pilch Jakub vs. Zika Tadeas... (1/150)
# Simulating Hrabec Michal vs. Zika Tadeas... (2/150)
# Simulating Burdik Vitezslav vs. Zika Tadeas... (3/150)
# Simulating Hrabec Michal vs. Pilch Jakub... (4/150)
# Simulating Burdik Vitezslav vs. Pilch Jakub... (5/150)
# Simulating Burdik Vitezslav vs. Hrabec Michal... (6/150)
# Simulating Louda Jiri vs. Vejvoda Viktor... (7/150)
# Simulating Hofman Denis vs. Louda Jiri... (8/150)
# Simulating Louda Jiri vs. Pikous Marcel... (9/150)
# Simulating Hofman Denis vs. Vejvoda Viktor... (10/150)
# Simulating Pikous Marcel vs. Vejvoda Viktor... (11/150)
# Simulating Hofman Denis vs. Pikous Marcel... (12/150)
# Simulating Briza Frantisek vs. Fisera Milan... (13/150)
# Simulating Briza Frantisek vs. Pavelka Radim... (14/150)
# Simulating Fisera Milan vs. Pavelka Radim... (15/150)
# Simulating Briza Frantisek vs. Kolar Milan... (16/150)
# Simulating Fisera Milan vs. Kolar Milan... (17/150)
# Simulating Kolar Milan vs. Pavelka Radim... (18/150)
# Simulating Andrle Tomas vs. Steffan Jan... (19/150)
# Simulating Andrle Tomas vs. Bartunek Radek... (20/150)
# Simulating Bartunek Radek vs. Hasmanda Rostislav... (21/150)
# Simulating Bartunek Radek vs. Steffan Jan... (22/150)
# Simulating Andrle Tomas vs. Hasmanda Rostislav... (23/150)
# Simulating Hasmanda Rostislav vs. Steffan Jan... (24/150)
# Simulating Petracek Vratislav vs. Postelt Tomas... (25/150)
# Simulating Bradac Petr vs. Petracek Vratislav... (26/150)
# Simulating Bradac Petr vs. Postelt Tomas... (27/150)
# Simulating Mares Erik vs. Petracek Vratislav... (28/150)
# Simulating Mares Erik vs. Postelt Tomas... (29/150)
# Simulating Bradac Petr vs. Mares Erik... (30/150)
# Simulating Bazalka Michal vs. Kalias Petr... (31/150)
# Simulating Kalias Petr vs. Opralka Roman... (32/150)
# Simulating Holubec Jiri vs. Kalias Petr... (33/150)
# Simulating Bazalka Michal vs. Holubec Jiri... (34/150)
# Simulating Bazalka Michal vs. Opralka Roman... (35/150)
# Simulating Holubec Jiri vs. Opralka Roman... (36/150)
# Simulating Petracek Vratislav vs. Turek Tomas... (37/150)
# Simulating Petracek Vratislav vs. Vavrecka Michal... (38/150)
# Simulating Turek Tomas vs. Vavrecka Michal... (39/150)
# Simulating Petracek Vratislav vs. Postelt Tomas... (40/150)
# Simulating Postelt Tomas vs. Turek Tomas... (41/150)
# Simulating Postelt Tomas vs. Vavrecka Michal... (42/150)
# Simulating Dedek Jiri vs. Vondra Pavel... (43/150)
# Simulating Briza Frantisek vs. Dedek Jiri... (44/150)
# Simulating Briza Frantisek vs. Vondra Pavel... (45/150)
# Simulating Dedek Jiri vs. Prokupek Jaroslav... (46/150)
# Simulating Briza Frantisek vs. Prokupek Jaroslav... (47/150)
# Simulating Prokupek Jaroslav vs. Vondra Pavel... (48/150)
# Simulating Kir Martin vs. Petrek Tomas... (49/150)
# Simulating Kir Martin vs. Vaclahovsky Oldrich... (50/150)
# Simulating Kir Martin vs. Nohejl Matej... (51/150)
# Simulating Nohejl Matej vs. Petrek Tomas... (52/150)
# Simulating Nohejl Matej vs. Vaclahovsky Oldrich... (53/150)
# Simulating Petrek Tomas vs. Vaclahovsky Oldrich... (54/150)
# Simulating Jezek Michal vs. Kanera Jan... (55/150)
# Simulating Fabini Marek vs. Kanera Jan... (56/150)
# Simulating Fabini Marek vs. Jezek Michal... (57/150)
# Simulating Fabini Marek vs. Huk Martin... (58/150)
# Simulating Huk Martin vs. Kanera Jan... (59/150)
# Simulating Huk Martin vs. Jezek Michal... (60/150)
# Simulating Kosar Vaclav vs. Tuma Miroslav... (61/150)
# Simulating Pycha Matej vs. Tuma Miroslav... (62/150)
# Simulating Kosar Vaclav vs. Pycha Matej... (63/150)
# Simulating Sudek Petr vs. Tuma Miroslav... (64/150)
# Simulating Kosar Vaclav vs. Sudek Petr... (65/150)
# Simulating Pycha Matej vs. Sudek Petr... (66/150)
# Simulating Kadavy Simon vs. Pycha Patrik... (67/150)
# Simulating Lasota Laurent vs. Pycha Patrik... (68/150)
# Simulating Kadavy Simon vs. Lasota Laurent... (69/150)
# Simulating Just Frantisek vs. Pycha Patrik... (70/150)
# Simulating Just Frantisek vs. Kadavy Simon... (71/150)
# Simulating Just Frantisek vs. Lasota Laurent... (72/150)
# Simulating Cetner Milan vs. Pospisil Milos... (73/150)
# Simulating Cetner Milan vs. Grohsgott Jiri... (74/150)
# Simulating Grohsgott Jiri vs. Pospisil Milos... (75/150)
# Simulating Cernik Jaromir vs. Cetner Milan... (76/150)
# Simulating Cernik Jaromir vs. Pospisil Milos... (77/150)
# Simulating Cernik Jaromir vs. Grohsgott Jiri... (78/150)
# Simulating Malek Lukas vs. Novotny Jaroslav... (79/150)
# Simulating Longin Milan vs. Novotny Jaroslav... (80/150)
# Simulating Dolezal Vaclav vs. Malek Lukas... (81/150)
# Simulating Dolezal Vaclav vs. Novotny Jaroslav... (82/150)
# Simulating Dolezal Vaclav vs. Longin Milan... (83/150)
# Simulating Longin Milan vs. Malek Lukas... (84/150)
# Simulating Byrtus Samuel vs. Kratochvil Roman... (85/150)
# Simulating Kratochvil Roman vs. Levicky Jakub... (86/150)
# Simulating Byrtus Samuel vs. Levicky Jakub... (87/150)
# Simulating Levicky Jakub vs. Stach Jiri... (88/150)
# Simulating Kratochvil Roman vs. Stach Jiri... (89/150)
# Simulating Byrtus Samuel vs. Stach Jiri... (90/150)
# Simulating Cabak Josef vs. Michna Viktor... (91/150)
# Simulating Michna Viktor vs. Smetka Pavel... (92/150)
# Simulating Cabak Josef vs. Rychlik Evzen... (93/150)
# Simulating Michna Viktor vs. Rychlik Evzen... (94/150)
# Simulating Rychlik Evzen vs. Smetka Pavel... (95/150)
# Simulating Cabak Josef vs. Smetka Pavel... (96/150)
# Simulating Vinter Tomas vs. Volf Matej... (97/150)
# Simulating Kolenic Tibor vs. Vinter Tomas... (98/150)
# Simulating Kolenic Tibor vs. Volf Matej... (99/150)
# Simulating Havlicek Vladimir vs. Vinter Tomas... (100/150)
# Simulating Havlicek Vladimir vs. Kolenic Tibor... (101/150)
# Simulating Havlicek Vladimir vs. Volf Matej... (102/150)
# Simulating Strnad Jaroslav 1964 vs. Tuma Miroslav... (103/150)
# Simulating Pycha Matej vs. Strnad Jaroslav 1964... (104/150)
# Simulating Kasinski Zdenek vs. Strnad Jaroslav 1964... (105/150)
# Simulating Kasinski Zdenek vs. Tuma Miroslav... (106/150)
# Simulating Kasinski Zdenek vs. Pycha Matej... (107/150)
# Simulating Pycha Matej vs. Tuma Miroslav... (108/150)
# Simulating Cetner Milan vs. Svec Jiri... (109/150)
# Simulating Grohsgott Jiri vs. Svec Jiri... (110/150)
# Simulating Cernik Jaromir vs. Svec Jiri... (111/150)
# Simulating Cetner Milan vs. Grohsgott Jiri... (112/150)
# Simulating Cernik Jaromir vs. Cetner Milan... (113/150)
# Simulating Cernik Jaromir vs. Grohsgott Jiri... (114/150)
# Simulating Havel Jiri vs. Strnad Jaroslav 1961... (115/150)
# Simulating Strnad Jaroslav 1961 vs. Vrabec Milan... (116/150)
# Simulating Havel Jiri vs. Vrabec Milan... (117/150)
# Simulating Kubat Vladimir vs. Strnad Jaroslav 1961... (118/150)
# Simulating Havel Jiri vs. Kubat Vladimir... (119/150)
# Simulating Kubat Vladimir vs. Vrabec Milan... (120/150)
# Simulating Fojt Pavel vs. Tuma Daniel... (121/150)
# Simulating Tuma Daniel vs. Vaclahovsky Oldrich... (122/150)
# Simulating Plachy Jiri vs. Tuma Daniel... (123/150)
# Simulating Fojt Pavel vs. Vaclahovsky Oldrich... (124/150)
# Simulating Prokupek Jaroslav vs. Tuma Daniel... (125/150)
# Simulating Fojt Pavel vs. Prokupek Jaroslav... (126/150)
# Simulating Prokupek Jaroslav vs. Vaclahovsky Oldrich... (127/150)
# Simulating Plachy Jiri vs. Prokupek Jaroslav... (128/150)
# Simulating Fojt Pavel vs. Plachy Jiri... (129/150)
# Simulating Plachy Jiri vs. Vaclahovsky Oldrich... (130/150)
# Simulating Smrcek Milan vs. Vitrovyj Oleg... (131/150)
# Simulating Smrcek Milan vs. Steffan Jan... (132/150)
# Simulating Hruska Vaclav senior vs. Smrcek Milan... (133/150)
# Simulating Regner Tomas vs. Smrcek Milan... (134/150)
# Simulating Steffan Jan vs. Vitrovyj Oleg... (135/150)
# Simulating Regner Tomas vs. Steffan Jan... (136/150)
# Simulating Hruska Vaclav senior vs. Vitrovyj Oleg... (137/150)
# Simulating Hruska Vaclav senior vs. Steffan Jan... (138/150)
# Simulating Hruska Vaclav senior vs. Regner Tomas... (139/150)
# Simulating Regner Tomas vs. Vitrovyj Oleg... (140/150)
# Simulating Huk Martin vs. Vavrecka Michal... (141/150)
# Simulating Huk Martin vs. Svacha Ondrej... (142/150)
# Simulating Huk Martin vs. Kliuchuk Rostyslav... (143/150)
# Simulating Huk Martin vs. Ruzicka Jiri... (144/150)
# Simulating Svacha Ondrej vs. Vavrecka Michal... (145/150)
# Simulating Kliuchuk Rostyslav vs. Vavrecka Michal... (146/150)
# Simulating Kliuchuk Rostyslav vs. Svacha Ondrej... (147/150)
# Simulating Ruzicka Jiri vs. Vavrecka Michal... (148/150)
# Simulating Ruzicka Jiri vs. Svacha Ondrej... (149/150)
# Simulating Kliuchuk Rostyslav vs. Ruzicka Jiri... (150/150)
# Finished in 517.9660952091217s

# %% [markdown]
# # Or use ipywidgets with the trader to trade/simulate matchups manually

# %%
import ipywidgets as widgets

playerWidget = widgets.Dropdown(options = trader.players, description = 'Player')
opponentWidget = widgets.Dropdown(options = trader.players, description = 'Opponent')
playerOddsWidget = widgets.IntText(value = -115, description = 'Away Odds')
opponentOddsWidget = widgets.IntText(value = -115, description = 'Home Odds')
players = widgets.VBox([playerWidget, opponentWidget])
odds = widgets.VBox([playerOddsWidget, opponentOddsWidget])
box = widgets.HBox([players, odds])
box
# Out:
# HBox(children=(VBox(children=(Dropdown(description='Player', options=('Adam Radim', 'Adamec Miroslav', 'Andrle…

# %%
# Set printToBetLog to true to write output to betLog.xlsx
trader.bet(playerWidget.value, opponentWidget.value, playerOddsWidget.value, opponentOddsWidget.value, writeToBetLog = False)
# Out:
# Adam Radim price: 49.84%
# Adam Radim price: 50.16%
#
#
# Adam Radim bet: 0
# Adam Radim bet: 0
